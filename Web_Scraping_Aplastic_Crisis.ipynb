# %% [markdown]
# <a href="https://colab.research.google.com/github/beejhay31/Sickle-Cell-Predictor/blob/main/Web_Scraping_Aplastic_Crisis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4) (4.6.3)

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
import requests
url = "https://wikem.org/wiki/Aplastic_crisis"
# makes a request to the web page and gets its HTML
r = requests.get(url)
# stores the HTML page in 'soup', a BeautifulSoup object
soup = BeautifulSoup(r.content,"lxml")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Aplastic crisis - WikEM
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
#    (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Aplastic_crisis","wgTitle":"Aplastic crisis","wgCurRevisionId":231227,"wgRevisionId":231227,"wgArticleId":5875,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["ID","Heme/Onc"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Aplastic_crisis","wgRelevantArticleId":5875,"wgRequestId":"Ya0yBuxs0GZ5ycQaOlLjhwAAAUI","wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgWikiEditorEnabledModules":[]});mw.loader.state({"site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","ext.smw.style":"ready","ext.smw.tooltip.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.wikem":"ready","skins.wikem.js":"loading"});mw.loader.implement("user.tokens@0hlix0m",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });mw.loader.load(["ext.smw.style","ext.smw.tooltips","ext.cite.a11y","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.toc","mediawiki.searchSuggest","ext.organicdesign","ext.gadget.ReferenceTooltips","ext.moderation.notify","ext.moderation.notify.desktop","skins.wikem.js"]);mw.loader.load("/w/load.php?debug=false\u0026lang=en\u0026modules=skins.wikem.js\u0026only=scripts\u0026skin=wikem");});
#   </script>
#   <link href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.cite.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.wikem&amp;only=styles&amp;skin=wikem" rel="stylesheet"/>
#   <link href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.smw.style%7Cext.smw.tooltip.styles&amp;only=styles&amp;skin=wikem" rel="stylesheet"/>
#   <script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=wikem">
#   </script>
#   <link href="//fonts.googleapis.com/css?family=Muli:400,700,900" rel="stylesheet"/>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=wikem" rel="stylesheet"/>
#   <meta content="MediaWiki 1.31.0" name="generator"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="no-cache" http-equiv="Pragma"/>
#   <meta content="no-cache" http-equiv="Pragma"/>
#   <link href="/w/index.php?title=Special:ExportRDF/Aplastic_crisis&amp;xmlmime=rdf" rel="alternate" title="Aplastic crisis" type="application/rdf+xml"/>
#   <link href="/w/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="/w/favicon.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="WikEM (en)" type="application/opensearchdescription+xml"/>
#   <link href="//wikem.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <meta content="app-id=576405449" name="apple-itunes-app"/>
#   <style type="text/css">
#    #editform .limitreport { display: none; }
# .ui-widget-content { width: 346px; }
#   </style>
#   <!--[if lt IE 9]><script src="/w/load.php?debug=false&amp;lang=en&amp;modules=html5shiv&amp;only=scripts&amp;skin=wikem&amp;sync=1"></script><![endif]-->
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Aplastic_crisis rootpage-Aplastic_crisis skin-wikem action-view">
#   <div id="wkm-wrapper">
#    <div id="wkm-sidebar">
#     <a class="mmenu-close" href="#">
#     </a>
#     <a class="wkm-logo" href="/wiki/Main_Page">
#      <img alt="WikEM" src="/w/skins/WikEM/img/logo.png?303"/>
#     </a>
#     <div class="wkm-search">
#      <form action="/w/index.php" id="searchform">
#       <input accesskey="f" id="searchInput" name="search" placeholder="Search" title="Search WikEM [f]" type="search"/>
#       <input name="title" type="hidden" value="Special:Search"/>
#       <input class="searchButton mw-fallbackSearchButton" id="mw-searchButton" name="fulltext" title="Search the pages for this text" type="submit" value=""/>
#       <input class="searchButton" id="searchButton" name="go" title="Go to a page with this exact name if it exists" type="submit" value=""/>
#      </form>
#     </div>
#     <div class="wkm-menu">
#      <ul>
#       <li id="n-Donate.21">
#        <a href="/wiki/Donate">
#         Donate!
#        </a>
#       </li>
#       <li id="n-Categories">
#        <a href="/wiki/Portal:Categories">
#         Categories
#        </a>
#       </li>
#       <li id="n-Mobile-Apps">
#        <a href="/wiki/WikEM:Mobile_Apps">
#         Mobile Apps
#        </a>
#       </li>
#       <li id="n-Journal-Club">
#        <a href="/wiki/WikEM:Journal_Club_Articles">
#         Journal Club
#        </a>
#       </li>
#       <li id="n-Antibiotics">
#        <a href="/wiki/Antibiotics_by_diagnosis">
#         Antibiotics
#        </a>
#       </li>
#       <li id="n-Quick-Critical-Care">
#        <a href="/wiki/Critical_care_quick_reference">
#         Quick Critical Care
#        </a>
#       </li>
#       <li id="n-Residency-Directory">
#        <a href="/wiki/Emergency_medicine_residency_programs">
#         Residency Directory
#        </a>
#       </li>
#       <li id="n-Recent-Changes">
#        <a href="/wiki/Special:RecentChanges">
#         Recent Changes
#        </a>
#       </li>
#       <li>
#        <a class="sub" href="#">
#         Using WikEM
#        </a>
#        <ul>
#         <li id="n-About-WikEM">
#          <a href="/wiki/WikEM:About">
#           About WikEM
#          </a>
#         </li>
#         <li id="n-Getting-Started">
#          <a href="/wiki/Getting_started">
#           Getting Started
#          </a>
#         </li>
#         <li id="n-Creating-.26-Editing">
#          <a href="/wiki/Updating_and_Creating_Notes_on_WikEM">
#           Creating &amp; Editing
#          </a>
#         </li>
#         <li id="n-Needed-Pages">
#          <a href="/wiki/Needed_pages">
#           Needed Pages
#          </a>
#         </li>
#         <li id="n-App-Help">
#          <a href="/wiki/Software_development">
#           App Help
#          </a>
#         </li>
#         <li id="n-Newsletter">
#          <a href="https://us7.list-manage.com/subscribe?u=671a2db89bb6addac1e8fbb0a&amp;id=37c18263d0" rel="nofollow">
#           Newsletter
#          </a>
#         </li>
#         <li id="n-EM-Forum">
#          <a href="http://forum.wikem.org" rel="nofollow">
#           EM Forum
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a class="sub" href="#">
#         Getting Credit
#        </a>
#        <ul>
#         <li id="n-Editorial-Levels">
#          <a href="/wiki/WikEM_editorial_levels">
#           Editorial Levels
#          </a>
#         </li>
#         <li id="n-Contribution-Score">
#          <a href="/wiki/Special:ContributionScores">
#           Contribution Score
#          </a>
#         </li>
#         <li id="n-Elective-Guide">
#          <a href="/wiki/WikEM_Elective_Guidelines">
#           Elective Guide
#          </a>
#         </li>
#         <li id="n-Citing-WikEM">
#          <a href="/wiki/Citing_WikEM">
#           Citing WikEM
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a class="sub" href="#">
#         Tools
#        </a>
#        <ul>
#         <li id="t-whatlinkshere">
#          <a accesskey="j" href="/wiki/Special:WhatLinksHere/Aplastic_crisis" title="A list of all wiki pages that link here [j]">
#           What links here
#          </a>
#         </li>
#         <li id="t-recentchangeslinked">
#          <a accesskey="k" href="/wiki/Special:RecentChangesLinked/Aplastic_crisis" rel="nofollow" title="Recent changes in pages linked from this page [k]">
#           Related changes
#          </a>
#         </li>
#         <li id="t-specialpages">
#          <a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]">
#           Special pages
#          </a>
#         </li>
#         <li id="t-print">
#          <a accesskey="p" href="/w/index.php?title=Aplastic_crisis&amp;printable=yes" rel="alternate" title="Printable version of this page [p]">
#           Printable version
#          </a>
#         </li>
#         <li id="t-permalink">
#          <a href="/w/index.php?title=Aplastic_crisis&amp;oldid=231227" title="Permanent link to this revision of the page">
#           Permanent link
#          </a>
#         </li>
#         <li id="t-info">
#          <a href="/w/index.php?title=Aplastic_crisis&amp;action=info" title="More information about this page">
#           Page information
#          </a>
#         </li>
#         <li id="t-smwbrowselink">
#          <a href="/wiki/Special:Browse/:Aplastic-5Fcrisis" rel="search">
#           Browse properties
#          </a>
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </div>
#     <div class="wkm-sponsor">
#      <a href="//emedharbor.edu" target="_blank">
#       <img alt="Harbor-UCLA" src="/w/skins/WikEM/img/harbor-ucla-logo.png?303"/>
#       <span>
#        Foundational
#        <br/>
#        Sponsor
#       </span>
#      </a>
#      <div class="clearfix">
#      </div>
#     </div>
#    </div>
#    <div id="wkm-content">
#     <div class="wkm-tmenu-wrap">
#      <ul class="wkm-tmenu fl">
#       <li class="more-menu">
#        <a class="nolink" href="#">
#         More
#        </a>
#       </li>
#       <li class="selected" id="ca-nstab-main">
#        <span>
#         <a accesskey="c" href="/wiki/Aplastic_crisis" title="View the content page [c]">
#          Page
#         </a>
#        </span>
#       </li>
#       <li class="new" id="ca-talk">
#        <span>
#         <a accesskey="t" href="/w/index.php?title=Talk:Aplastic_crisis&amp;action=edit&amp;redlink=1" rel="discussion" title="Discussion about the content page [t]">
#          Discussion
#         </a>
#        </span>
#       </li>
#       <li class="selected" id="ca-view">
#        <span>
#         <a href="/wiki/Aplastic_crisis">
#          View
#         </a>
#        </span>
#       </li>
#       <li id="ca-viewsource">
#        <span>
#         <a accesskey="e" href="/w/index.php?title=Aplastic_crisis&amp;action=edit" title="This page is protected.
# You can view its source [e]">
#          View source
#         </a>
#        </span>
#       </li>
#       <li class="collapsible" id="ca-history">
#        <span>
#         <a accesskey="h" href="/w/index.php?title=Aplastic_crisis&amp;action=history" title="Past revisions of this page [h]">
#          History
#         </a>
#        </span>
#       </li>
#      </ul>
#      <ul class="wkm-tmenu fr">
#       <li id="pt-createaccount">
#        <a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Aplastic+crisis" title="You are encouraged to create an account and log in; however, it is not mandatory">
#         Create account
#        </a>
#       </li>
#       <li id="pt-login">
#        <a accesskey="o" href="/w/index.php?title=Special:UserLogin&amp;returnto=Aplastic+crisis" title="You are encouraged to log in; however, it is not mandatory [o]">
#         Log in
#        </a>
#       </li>
#      </ul>
#      <div class="clearfix">
#      </div>
#     </div>
#     <div class="wkm-tmenu-mobile">
#      <a class="mmenu-show" href="#">
#      </a>
#      <a class="logo" href="/wiki/Main_Page">
#       <img alt="WikEM" src="/w/skins/WikEM/img/logo-mobile.png?303"/>
#      </a>
#      <a class="user-menu" href="#">
#      </a>
#     </div>
#     <div class="wkm-note">
#      <div dir="ltr" id="localNotice" lang="en">
#       <div class="mw-parser-output">
#        <p>
#         <a href="/wiki/Donate" title="Donate">
#          Please donate!
#         </a>
#         Funds go solely to hosting and development costs that allow medical practitioners around the globe to freely access WikEM.
#        </p>
#       </div>
#      </div>
#     </div>
#     <div class="clearfix">
#     </div>
#     <div class="mw-body" id="content" role="main">
#      <a id="top">
#      </a>
#      <h1 class="firstHeading" id="firstHeading">
#       Aplastic crisis
#      </h1>
#      <div class="mw-body-content" id="bodyContent">
#       <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#        <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#         <div class="mw-parser-output">
#          <div class="toc" id="toc">
#           <div class="toctitle" dir="ltr" lang="en">
#            <h2>
#             Contents
#            </h2>
#           </div>
#           <ul>
#            <li class="toclevel-1 tocsection-1">
#             <a href="#Background">
#              <span class="tocnumber">
#               1
#              </span>
#              <span class="toctext">
#               Background
#              </span>
#             </a>
#            </li>
#            <li class="toclevel-1 tocsection-2">
#             <a href="#Clinical_Features">
#              <span class="tocnumber">
#               2
#              </span>
#              <span class="toctext">
#               Clinical Features
#              </span>
#             </a>
#            </li>
#            <li class="toclevel-1 tocsection-3">
#             <a href="#Causes">
#              <span class="tocnumber">
#               3
#              </span>
#              <span class="toctext">
#               Causes
#              </span>
#             </a>
#            </li>
#            <li class="toclevel-1 tocsection-4">
#             <a href="#Labs">
#              <span class="tocnumber">
#               4
#              </span>
#              <span class="toctext">
#               Labs
#              </span>
#             </a>
#            </li>
#            <li class="toclevel-1 tocsection-5">
#             <a href="#Management">
#              <span class="tocnumber">
#               5
#              </span>
#              <span class="toctext">
#               Management
#              </span>
#             </a>
#            </li>
#            <li class="toclevel-1 tocsection-6">
#             <a href="#Recovery_Phase">
#              <span class="tocnumber">
#               6
#              </span>
#              <span class="toctext">
#               Recovery Phase
#              </span>
#             </a>
#            </li>
#            <li class="toclevel-1 tocsection-7">
#             <a href="#Disposition">
#              <span class="tocnumber">
#               7
#              </span>
#              <span class="toctext">
#               Disposition
#              </span>
#             </a>
#            </li>
#            <li class="toclevel-1 tocsection-8">
#             <a href="#Also_See">
#              <span class="tocnumber">
#               8
#              </span>
#              <span class="toctext">
#               Also See
#              </span>
#             </a>
#            </li>
#            <li class="toclevel-1 tocsection-9">
#             <a href="#References">
#              <span class="tocnumber">
#               9
#              </span>
#              <span class="toctext">
#               References
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#          <h2>
#           <span class="mw-headline" id="Background">
#            Background
#           </span>
#          </h2>
#          <ul>
#           <li>
#            Also called Reticulocytopenia: abnormal decrease of reticulocytes in the body
#           </li>
#           <li>
#            Clinically common in
#            <a href="/wiki/Sickle_cell_crisis" title="Sickle cell crisis">
#             Sickle cell crisis
#            </a>
#            and
#            <a class="mw-redirect" href="/wiki/Hereditary_Spherocytosis_(HS)" title="Hereditary Spherocytosis (HS)">
#             Hereditary Spherocytosis (HS)
#            </a>
#           </li>
#          </ul>
#          <h2>
#           <span class="mw-headline" id="Clinical_Features">
#            Clinical Features
#           </span>
#          </h2>
#          <ul>
#           <li>
#            <a href="/wiki/Sickle_cell_crisis" title="Sickle cell crisis">
#             Sickle cell crisis
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Anemia" title="Anemia">
#             Anemia
#            </a>
#           </li>
#           <li>
#            Increased
#            <a class="mw-redirect" href="/wiki/Fatigue" title="Fatigue">
#             fatigue
#            </a>
#            , pallor
#           </li>
#           <li>
#            Activity intolerance
#           </li>
#           <li>
#            <a class="mw-redirect" href="/wiki/Shortness_of_breath" title="Shortness of breath">
#             Shortness of breath
#            </a>
#           </li>
#          </ul>
#          <h2>
#           <span class="mw-headline" id="Causes">
#            Causes
#           </span>
#          </h2>
#          <ul>
#           <li>
#            <a class="mw-redirect" href="/wiki/Erythema_Infectiosum_(Fifth_disease)" title="Erythema Infectiosum (Fifth disease)">
#             Erythema Infectiosum (Fifth disease)
#            </a>
#            <ul>
#             <li>
#              Invades and destroys red blood cell precursors and halts the red cell production
#             </li>
#            </ul>
#           </li>
#           <li>
#            <a class="mw-redirect" href="/wiki/EBV" title="EBV">
#             EBV
#            </a>
#           </li>
#           <li>
#            <a class="mw-redirect" href="/wiki/Strep" title="Strep">
#             Strep
#            </a>
#            infection
#           </li>
#           <li>
#            Use of
#            <a href="/wiki/Hydroxyurea" title="Hydroxyurea">
#             hydroxyurea
#            </a>
#           </li>
#          </ul>
#          <h2>
#           <span class="mw-headline" id="Labs">
#            Labs
#           </span>
#          </h2>
#          <ul>
#           <li>
#            CBC with retic count
#            <ul>
#             <li>
#              <a href="/wiki/Anemia" title="Anemia">
#               Decrease from baseline hemoglobin/hematocrit
#              </a>
#             </li>
#             <li>
#              Precipitous drop in reticulocyte count (or lack of response)
#             </li>
#            </ul>
#           </li>
#          </ul>
#          <h2>
#           <span class="mw-headline" id="Management">
#            Management
#           </span>
#          </h2>
#          <ul>
#           <li>
#            <a class="mw-redirect" href="/wiki/PRBCs" title="PRBCs">
#             Transfusion
#            </a>
#            using extended antigen-typed, leuko-depleted pRBCs
#           </li>
#           <li>
#            Droplet precautions
#           </li>
#          </ul>
#          <h2>
#           <span class="mw-headline" id="Recovery_Phase">
#            Recovery Phase
#           </span>
#          </h2>
#          <ul>
#           <li>
#            Typically in 1-2 weeks
#           </li>
#           <li>
#            Often marked by hyperbilirubinemia, and called a “hyperhemolytic” phase
#            <sup class="reference" id="cite_ref-1">
#             <a href="#cite_note-1">
#              [1]
#             </a>
#            </sup>
#           </li>
#          </ul>
#          <h2>
#           <span class="mw-headline" id="Disposition">
#            Disposition
#           </span>
#          </h2>
#          <ul>
#           <li>
#            Admit
#           </li>
#          </ul>
#          <h2>
#           <span class="mw-headline" id="Also_See">
#            Also See
#           </span>
#          </h2>
#          <ul>
#           <li>
#            <a class="mw-redirect" href="/wiki/Erythema_Infectiosum_(Fifth_disease)" title="Erythema Infectiosum (Fifth disease)">
#             Erythema Infectiosum (Fifth disease)
#            </a>
#           </li>
#           <li>
#            <a class="mw-redirect" href="/wiki/Hereditary_Spherocytosis_(HS)" title="Hereditary Spherocytosis (HS)">
#             Hereditary Spherocytosis (HS)
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Sickle_cell_crisis" title="Sickle cell crisis">
#             Sickle cell crisis
#            </a>
#           </li>
#          </ul>
#          <h2>
#           <span class="mw-headline" id="References">
#            References
#           </span>
#          </h2>
#          <div class="mw-references-wrap">
#           <ol class="references">
#            <li id="cite_note-1">
#             <span class="mw-cite-backlink">
#              <a href="#cite_ref-1">
#               ↑
#              </a>
#             </span>
#             <span class="reference-text">
#              <a class="external free" href="http://www.ihtc.org/medical-professionals/blood-disorders/sickle-cell-disease/aplastic-crisis-intervention/" rel="nofollow">
#               http://www.ihtc.org/medical-professionals/blood-disorders/sickle-cell-disease/aplastic-crisis-intervention/
#              </a>
#             </span>
#            </li>
#           </ol>
#          </div>
#          <ul>
#           <li>
#            Janz TJ, Hamilton GC: Anemia, Polycythemia, and White Blood Cell Disorders, in Marx JA, Hockberger RS, Walls RM, et al (eds): Rosen’s Emergency Medicine: Concepts and Clinical Practice, ed 7. St. Louis, Mosby, Inc., 2010, (Ch) 119:p 1568-1574.
#           </li>
#           <li>
#            <a class="external free" href="http://www.ihtc.org/medical-professionals/blood-disorders/sickle-cell-disease/aplastic-crisis-intervention/" rel="nofollow">
#             http://www.ihtc.org/medical-professionals/blood-disorders/sickle-cell-disease/aplastic-crisis-intervention/
#            </a>
#            - last accessed 1/6/15
#           </li>
#          </ul>
#         </div>
#         <!-- Saved in parser cache with key wikidb:pcache:idhash:5875-0!canonical and timestamp 20211205211131 and revision id 231227
#  -->
#        </div>
#        <div class="printfooter">
#         Retrieved from "
#         <a dir="ltr" href="https://www.wikem.org/w/index.php?title=Aplastic_crisis&amp;oldid=231227">
#          https://www.wikem.org/w/index.php?title=Aplastic_crisis&amp;oldid=231227
#         </a>
#         "
#        </div>
#        <div class="catlinks" data-mw="interface" id="catlinks">
#         <div class="mw-normal-catlinks" id="mw-normal-catlinks">
#          <a href="/wiki/Special:Categories" title="Special:Categories">
#           Categories
#          </a>
#          :
#          <ul>
#           <li>
#            <a href="/wiki/Category:ID" title="Category:ID">
#             ID
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Heme/Onc" title="Category:Heme/Onc">
#             Heme/Onc
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div id="mw-data-after-content">
#         <div id="authors">
#          <span>
#           Authors
#          </span>
#          :
#          <ul>
#           <li>
#            <a class="mw-userlink" href="/wiki/User:Adamhaag" title="User:Adamhaag">
#             <bdi>
#              adam haag
#             </bdi>
#            </a>
#           </li>
#           <li>
#            <a class="mw-userlink" href="/wiki/User:Arsmd" title="User:Arsmd">
#             <bdi>
#              Aaron Snyder
#             </bdi>
#            </a>
#           </li>
#           <li>
#            <a class="mw-userlink" href="/wiki/User:ClaireLewis" title="User:ClaireLewis">
#             <bdi>
#              Claire
#             </bdi>
#            </a>
#           </li>
#           <li>
#            <a class="mw-userlink" href="/wiki/User:Neil.m.young" title="User:Neil.m.young">
#             <bdi>
#              Neil Young
#             </bdi>
#            </a>
#           </li>
#           <li>
#            <a class="mw-userlink" href="/wiki/User:Rossdonaldson1" title="User:Rossdonaldson1">
#             <bdi>
#              Ross Donaldson
#             </bdi>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="clearfix">
#     </div>
#     <div id="wkm-footer">
#      <ul>
#       <li>
#        <a href="/wiki/WikEM:Privacy_policy" title="WikEM:Privacy policy">
#         Privacy policy
#        </a>
#       </li>
#       <li>
#        <a href="/wiki/WikEM:About" title="WikEM:About">
#         About WikEM
#        </a>
#       </li>
#       <li>
#        <a href="/wiki/WikEM:General_disclaimer" title="WikEM:General disclaimer">
#         Disclaimers
#        </a>
#       </li>
#      </ul>
#      <span>
#       This page was last edited 23:40, 30 September 2019 by
#       <a href="/wiki/User:ClaireLewis" title="User:ClaireLewis">
#        Claire
#       </a>
#       .
#      </span>
#      <a class="btn-donate" href="https://www.paypal.com/cgi-bin/webscr?cmd=_s-xclick&amp;hosted_button_id=YE2QYMKQTYSUY" target="_blank">
#       Donate
#      </a>
#     </div>
#    </div>
#    <div class="clearfix">
#    </div>
#   </div>
#   <script>
#    (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"smw":{"limitreport-intext-parsertime":0}}});});
#   </script>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-22356067-1', 'auto');
#   ga('set', 'anonymizeIp', true);
#   ga('send', 'pageview');
#   </script>
#   <script>
#    (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":1674});});
#   </script>
#  </body>
# </html>

# %%
df2 = pd.DataFrame(columns =['Subheading', 'List1'])
#heading = []
subheading2 = []
lists2 = []
#lists2 = []
flag1 = 0
for link2 in soup.find_all("h2"):
  if flag1 == 0:
    subheading2.append(link2.get_text())
    next_sib2 = link2.find_next_sibling(['ul', 'h2'])
    if next_sib2 is not None:
      print(next_sib2.get_text())
      text2 = []
      if next_sib2 is not None:
        while next_sib2.name != 'h2':
          text2.append(next_sib2.get_text())
          next_sib2 = next_sib2.find_next_sibling(['ul','h2'])
          if next_sib2 is None :
            flag1 = 1
            break
        lists2.append(' '.join(text2))
      else:
        break
df2['Subheading'] = subheading2
df2 = df2.drop(index=0)
df2["List1"] = lists2
# Out:
# Also called Reticulocytopenia: abnormal decrease of reticulocytes in the body
# Clinically common in Sickle cell crisis and Hereditary Spherocytosis (HS)
# Sickle cell crisis
# Anemia
# Increased fatigue, pallor
# Activity intolerance
# Shortness of breath
# Erythema Infectiosum (Fifth disease)
# Invades and destroys red blood cell precursors and halts the red cell production
# EBV
# Strep infection
# Use of hydroxyurea
# CBC with retic count
# Decrease from baseline hemoglobin/hematocrit
# Precipitous drop in reticulocyte count (or lack of response)
# Transfusion using extended antigen-typed, leuko-depleted pRBCs
# Droplet precautions
# Typically in 1-2 weeks
# Often marked by hyperbilirubinemia, and called a “hyperhemolytic” phase[1]
# Admit
# Erythema Infectiosum (Fifth disease)
# Hereditary Spherocytosis (HS)
# Sickle cell crisis
# Janz TJ, Hamilton GC: Anemia, Polycythemia, and White Blood Cell Disorders, in Marx JA, Hockberger RS, Walls RM, et al (eds): Rosen’s Emergency Medicine: Concepts and Clinical Practice, ed 7. St. Louis, Mosby, Inc., 2010, (Ch) 119:p 1568-1574.
# http://www.ihtc.org/medical-professionals/blood-disorders/sickle-cell-disease/aplastic-crisis-intervention/ - last accessed 1/6/15

# %%
df2
# Out:
#           Subheading                                              List1
# 1         Background  Also called Reticulocytopenia: abnormal decrea...
# 2  Clinical Features  Sickle cell crisis\nAnemia\nIncreased fatigue,...
# 3             Causes  Erythema Infectiosum (Fifth disease)\nInvades ...
# 4               Labs  CBC with retic count\nDecrease from baseline h...
# 5         Management  Transfusion using extended antigen-typed, leuk...
# 6     Recovery Phase  Typically in 1-2 weeks\nOften marked by hyperb...
# 7        Disposition                                              Admit
# 8           Also See  Erythema Infectiosum (Fifth disease)\nHeredita...
# 9         References  Janz TJ, Hamilton GC: Anemia, Polycythemia, an...

# %%
df2 = df2.drop(index=[8,9])

# %%
df2
# Out:
#           Subheading                                              List1
# 1         Background  Also called Reticulocytopenia: abnormal decrea...
# 2  Clinical Features  Sickle cell crisis\nAnemia\nIncreased fatigue,...
# 3             Causes  Erythema Infectiosum (Fifth disease)\nInvades ...
# 4               Labs  CBC with retic count\nDecrease from baseline h...
# 5         Management  Transfusion using extended antigen-typed, leuk...
# 6     Recovery Phase  Typically in 1-2 weeks\nOften marked by hyperb...
# 7        Disposition                                              Admit

# %%
df2.to_csv("Aplastic.csv")
